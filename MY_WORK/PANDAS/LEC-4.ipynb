# %% [markdown]
# ****create plots in pandas****

# %%
#import pandas
import pandas as pd
#import matplot
import matplotlib.pyplot as plt

# %%
#read the CSV file
Olympics=pd.read_csv("Paris 2024 Olympics_Nations Medals.csv")
Olympics.head()
# Out:
#    NOC  Gold  Silver  Bronze  Total
# 0  USA    40      44      42    126
# 1  CHN    40      27      24     91
# 2  JPN    20      12      13     45
# 3  AUS    18      19      16     53
# 4  FRA    16      26      22     64

# %% [markdown]
# ****Note****
#
# The usage of the "index_col" and "parse_dates" parameters of the read_csv function to define the first (0th) column as index of the resulting DataFrame and convert the dates in the column to Timestamp objects, respectively.

# %% [markdown]
# I want a quick visual check of the data.

# %%
Olympics.plot()
plt.show()

# %% [markdown]
# With a DataFrame, pandas creates by default one line plot for each of the columns with numeric data.

# %% [markdown]
# I want to plot only the columns of the data table with the data from Olympics
# .

# %%
Olympics["Gold"].plot()
plt.show()

# %% [markdown]
# To plot a specific column, use the selection method of the subset data tutorial in combination with the plot() method. Hence, the plot() method works on both Series and DataFrame.

# %% [markdown]
# I want to visually compare the values measured in NOC versus Gold.

# %%
Olympics.plot.scatter(x='NOC',y='Gold',alpha=0.5)
plt.show()

# %% [markdown]
# Apart from the default line plot when using the plot function, a number of alternatives are available to plot data. Let’s use some standard Python to get an overview of the available plot methods:

# %%
[
    method_name
    for method_name in dir(Olympics.plot)
    if not method_name.startswith("_")
]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %% [markdown]
# Note
#
# In many development environments as well as IPython and Jupyter Notebook, use the TAB button to get an overview of the available methods, for example Olympics.plot. + TAB

# %% [markdown]
# One of the options is DataFrame.plot.box(), which refers to a boxplot.

# %%
Olympics.boxplot()
plt.show()

# %% [markdown]
# I want each of the columns in a separate subplot

# %%
#When subploat are false// single area plot
axs = Olympics.plot.area(figsize=(10, 4), subplots=False)
plt.show()

# %%
#When subploats atr true// separet area plot
Olympics.plot.area(figsize=(10, 4), subplots=True)
plt.show()

# %% [markdown]
# Separate subplots for each of the data columns are supported by the subplots argument of the plot functions. The builtin options available in each of the pandas plot functions are worth reviewing.

# %% [markdown]
# I want to further customize, extend or save the resulting plot.

# %%
fig, axs = plt.subplots(figsize=(12, 4)) # Create an empty Matplotlib Figure and Axes
Olympics.plot.area(ax=axs)               # Use pandas to put the area plot on the prepared Figure/Axes
axs.set_ylabel("Number of medal")        # Do any Matplotlib customization you like
axs.set_xlabel("NOC")                  
fig.savefig("Graph.png")                 # Save the Figure/Axes using the existing Matplotlib method.       

plt.show()                               # Display the plot

# %% [markdown]
# Each of the plot objects created by pandas is a Matplotlib object. As Matplotlib provides plenty of options to customize plots, making the link between pandas and Matplotlib explicit enables all the power of Matplotlib to the plot.

# %% [markdown]
# ****REMEMBER:--****
#
# The .plot.* methods are applicable on both Series and DataFrames.
#
# By default, each of the columns is plotted as a different element (line, boxplot,…).
#
# Any plot created by pandas is a Matplotlib object.
