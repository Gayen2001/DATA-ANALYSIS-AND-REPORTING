# %% [markdown]
# Q-1.Import of a pie chart using python

# %%
from matplotlib import pyplot as plt
import numpy as np
cars=["AUDI","BMW","FORD","TESLA","JAGUAR"]
data=[23,17,35,29,12]
fig=plt.figure(figsize=(10,7))
plt.pie(data,labels=cars)
plt.show()
